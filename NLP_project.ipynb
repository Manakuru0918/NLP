# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# Try mounting with troubleshooting flags
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Try reading with error handling and a different delimiter if necessary
Fake = pd.read_csv("/content/drive/MyDrive/Fake.csv", encoding='latin-1', on_bad_lines='warn', sep=',')
# The 'on_bad_lines' argument will print a warning for lines with errors and skip them
Fake.head()
# Out:
# Skipping line 9096: expected 4 fields, saw 39
# Skipping line 9097: expected 4 fields, saw 39
# Skipping line 9298: expected 4 fields, saw 59
# Skipping line 9644: expected 4 fields, saw 17
# Skipping line 9683: expected 4 fields, saw 24
# Skipping line 9759: expected 4 fields, saw 12
# Skipping line 9825: expected 4 fields, saw 35
# Skipping line 10117: expected 4 fields, saw 18
# Skipping line 10240: expected 4 fields, saw 87
# Skipping line 11713: expected 4 fields, saw 8
# Skipping line 12289: expected 4 fields, saw 10
# Skipping line 15993: expected 4 fields, saw 87
# Skipping line 17470: expected 4 fields, saw 39
# Skipping line 17579: expected 4 fields, saw 59
# Skipping line 17786: expected 4 fields, saw 17
# Skipping line 17812: expected 4 fields, saw 24
# Skipping line 17921: expected 4 fields, saw 35
# Skipping line 18117: expected 4 fields, saw 18
# Skipping line 18215: expected 4 fields, saw 87
# Skipping line 19179: expected 4 fields, saw 8
# ...

# %%
true=pd.read_excel("/content/drive/MyDrive/True.xlsx")
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                   date Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  2017-12-31 00:00:00        NaN        NaN        NaN        NaT
# 1  2017-12-29 00:00:00        NaN        NaN        NaN        NaT
# ...

# %%
Fake["subject"].value_counts()
# Out:
# subject
# News               9050
# politics           6829
# left-news          4450
# Government News    1569
# US_News             783
# Middle-east         778
# Mar 14, 2016          1
# Name: count, dtype: int64

# %%
#creating categoery whether true or fake
true["category"]=0
Fake["category"]=1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                   date Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  category
# 0  2017-12-31 00:00:00        NaN        NaN        NaN        NaT         0
# 1  2017-12-29 00:00:00        NaN        NaN        NaN        NaT         0
# ...

# %%
Fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamas Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
#Joining the two data frames and resetting the indexing
df = pd.concat([true,Fake]).reset_index(drop=True)

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                   date Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  category
# 0  2017-12-31 00:00:00        NaN        NaN        NaN        NaT         0
# 1  2017-12-29 00:00:00        NaN        NaN        NaN        NaT         0
# ...

# %%
df.count()
# Out:
# title         44879
# text          44876
# subject       44877
# date          44876
# Unnamed: 4        1
# Unnamed: 5        1
# Unnamed: 6        1
# Unnamed: 7        1
# category      44879
# dtype: int64

# %%
import matplotlib.pyplot as plt
#Joining the two data frames, adding a 'label' column and resetting the indexing
true['label'] = 'true'  # Add a 'label' column to the 'true' DataFrame
Fake['label'] = 'fake'  # Add a 'label' column to the 'Fake' DataFrame
df = pd.concat([true,Fake]).reset_index(drop=True)

plt.figure(figsize=(10,5))
sns.countplot(x='label',data=df)  # Now 'label' column exists in 'df'
plt.title("Distribution of Real and Fake News")
plt.show()

# %%
df.count()
# Out:
# title         44879
# text          44876
# subject       44877
# date          44876
# Unnamed: 4        1
# Unnamed: 5        1
# Unnamed: 6        1
# Unnamed: 7        1
# category      44879
# label         44879
# dtype: int64

# %%
print(df.columns)  # Check if 'subject' is present in the DataFrame
# Out:
# Index(['title', 'text', 'subject', 'date', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'category', 'label'],
#       dtype='object')

# %%
df = df[["text","category"]]

# %%
df
# Out:
#                                                     text  category
# 0      WASHINGTON (Reuters) - The head of a conservat...         0
# 1      WASHINGTON (Reuters) - Transgender people will...         0
# 2      WASHINGTON (Reuters) - The special counsel inv...         0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...         0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...         0
# ...                                                  ...       ...
# 44874  21st Century Wire says As 21WIRE reported earl...         1
# 44875  21st Century Wire says It s a familiar theme. ...         1
# 44876  Patrick Henningsen  21st Century WireRemember ...         1
# 44877  21st Century Wire says Al Jazeera America will...         1
# 44878  21st Century Wire says As 21WIRE predicted in ...         1
#
# [44879 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# text        3
# category    0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                     text  category
# 0      WASHINGTON (Reuters) - The head of a conservat...         0
# 1      WASHINGTON (Reuters) - Transgender people will...         0
# 2      WASHINGTON (Reuters) - The special counsel inv...         0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...         0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...         0
# ...                                                  ...       ...
# 44874  21st Century Wire says As 21WIRE reported earl...         1
# 44875  21st Century Wire says It s a familiar theme. ...         1
# 44876  Patrick Henningsen  21st Century WireRemember ...         1
# 44877  21st Century Wire says Al Jazeera America will...         1
# 44878  21st Century Wire says As 21WIRE predicted in ...         1
#
# [44876 rows x 2 columns]

# %%
df.count()
# Out:
# text        44876
# category    44879
# dtype: int64

# %%
import pandas as pd
# Find indices of rows with empty or whitespace-only strings in the 'text' column
blanks = df[df['text'].apply(lambda x: isinstance(x, str) and x.strip() == '')].index

# Print the count of blank rows
print(f'Number of rows with blanks: {len(blanks)}')

# Print the indices of blank rows
print(f'Indices of rows with blanks: {list(blanks)}')
# Out:
# Number of rows with blanks: 630
# ...

# %%
import pandas as pd
# Drop rows where 'text' column contains empty strings or whitespace-only strings
df = df[df['text'].apply(lambda x: isinstance(x, str) and x.strip() != '')]

# Reset the index if needed
df.reset_index(drop=True, inplace=True)

# Print the number of rows remaining
print(f'Number of rows after cleaning: {len(df)}')
# Out:
# Number of rows after cleaning: 44246

# %%
df.shape
# Out:
# (44246, 2)

# %%
df
# Out:
#                                                     text  category
# 0      WASHINGTON (Reuters) - The head of a conservat...         0
# 1      WASHINGTON (Reuters) - Transgender people will...         0
# 2      WASHINGTON (Reuters) - The special counsel inv...         0
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...         0
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...         0
# ...                                                  ...       ...
# 44241  21st Century Wire says As 21WIRE reported earl...         1
# 44242  21st Century Wire says It s a familiar theme. ...         1
# 44243  Patrick Henningsen  21st Century WireRemember ...         1
# 44244  21st Century Wire says Al Jazeera America will...         1
# 44245  21st Century Wire says As 21WIRE predicted in ...         1
#
# [44246 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk. stem import WordNetLemmatizer
import re
import spacy
import string
nlp= spacy.load('en_core_web_sm')

lemma = WordNetLemmatizer()

# stopwords of spacy
list1 = nlp.Defaults.stop_words
print(len(list1))

#stopwords of nltk
list2 = stopwords.words('english') # This should now work after downloading the corpus.
print(len(list2))

#combined stopwords
list3 = list1.union(list2)
print(len(list3))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 326
# 179
# 382

# %%
def clean_text(text):
  string = ''
  text = text.lower()
# Removing aphostrophy
  text = re .sub(r"i'm", "i am", text)
  text = re.sub(r"he's", "he is", text)
  text = re.sub(r"she's", "she is", text)
  text = re.sub(r"it's", "it is", text)
  text = re.sub(r"that's", "that is", text)
  text = re.sub(r"what's", "that is", text)
  text = re.sub(r"where's", "where is", text)
  text = re.sub(r"how's", "how is", text)
  text = re.sub(r"\'ll", " will", text)
  text = re.sub(r"\'ve", " have", text)
  text = re.sub(r"\'re", " are", text)
  text = re.sub(r"\'d", " would", text)
  text = re.sub(r"\'re", " are", text)
  text = re.sub(r"won't", "will not", text)
  text = re.sub(r"can't", "cannot", text)
  text = re.sub(r"n't", " not", text)
# removing any special characters
  text = re.sub(r"[-()\"#!@$^&{}.,:;<>]","",text)
  text = re.sub(r"\s+", " ", text)
  text = re.sub(r"\d+", "", text)
  text = re.sub('[^A-Za-z0-9]+', ' ', text)

  for word in text.split():
    if word not in list3:
      string += lemma.lemmatize(word) + " "

  return string

# %%
df["text"][250]
# Out:
# 'WASHINGTON (Reuters) - President Donald Trump_x0019_s weekend remark about a scaled-back tax cut for corporations sparked behind-the-scenes debate in the U.S. Congress, with a White House aide trying on Thursday to minimize the impact of the president_x0019_s comment. Two rival tax bills, passed separately by the Senate and the House of Representatives, propose cutting the U.S. corporate tax rate to 20 percent, but they differ in other areas that Republicans are trying to merge into final legislation. Speaking to reporters after the Senate approved its tax bill on Saturday, Trump said the corporate tax rate in the final legislation, expected soon from lawmakers, _x001c_could be 22 (percent) ... it could also be 20 (percent)._x001d_ The remark whetted the interest of some Republicans who see a slight upward bump in the proposed corporate tax rate as  capturing needed federal revenue that would help solve other problems with the legislation, according to lobbyists.  _x001c_The 20 perc
# ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
clean_text(df["text"][250])
# Out:
# 'washington reuters president donald trump x weekend remark scaledback tax cut corporation sparked behindthescenes debate congress white house aide trying thursday minimize impact president x comment rival tax bill passed separately senate house representative propose cutting corporate tax rate percent differ area republican trying merge final legislation speaking reporter senate approved tax bill saturday trump said corporate tax rate final legislation expected soon lawmaker xc percent percent xd remark whetted interest republican slight upward bump proposed corporate tax rate capturing needed federal revenue help solve problem legislation according lobbyist xc percent rate ought goal xd said house way mean committee chairman kevin brady expected head bicameral housesenate negotiating committee xc view president giving flexibility area x needed decision x x needed xd texas republican told reporter white house legislative affair director marc short told reuters thursday trump voicing
# ...

# %%
df["text"] = df["text"].apply(clean_text)
# Out:
# <ipython-input-40-469795bba951>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"] = df["text"].apply(clean_text)

# %%
df["text"]
# Out:
# 0        washington reuters head conservative republica...
# 1        washington reuters transgender people allowed ...
# 2        washington reuters special counsel investigati...
# 3        washington reuters trump campaign adviser geor...
# 4        seattle washington reuters president donald tr...
#                                ...
# 44241    st century wire say wire reported earlier week...
# 44242    st century wire say familiar theme dispute cha...
# 44243    patrick henningsen st century wireremember oba...
# 44244    st century wire say al jazeera america history...
# 44245    st century wire say wire predicted new year lo...
# Name: text, Length: 44246, dtype: object

# %% [markdown]
# # word cloud

# %%
from wordcloud import wordcloud

# %%
from wordcloud import WordCloud # Import the WordCloud class
import matplotlib.pyplot as plt

#True news
plt.figure(figsize=(10,10))
# Instantiate a WordCloud object
Wc = WordCloud(max_words = 500, width =1500, height = 1000).generate(" ".join(df[df["category"]==0]["text"]))
plt.imshow(Wc)

# %%
# !pip install wordcloud
from wordcloud import WordCloud  # Import the WordCloud class
import matplotlib.pyplot as plt

#True news
plt.figure(figsize=(10,10))
Wc = WordCloud(max_words = 500, width =1500, height = 1000).generate(" ".join(df[df["category"]==0]["text"])) # Use the WordCloud class to create a word cloud object
plt.imshow(Wc)

# %%
#pil is pillow and used for image manupulation
from PIL import Image
import numpy as np

# %%
thumb="/content/drive/MyDrive/thumbs-up.png"
icon=Image.open(thumb)
mask=Image.new(mode="RGB",size=icon.size, color=(255,255,255))
mask.paste(icon, box=icon)

rgb_array=np.array(mask)

# %%
#True News
plt.figure(figsize = (10,10))
Wc = WordCloud(mask=rgb_array,max_words = 2000 , width = 1600 ,
               height = 800)

Wc.generate(" ".join(df[df.category == 0].text))
plt.axis("off")
plt.imshow(Wc , interpolation = 'bilinear')

# %%
#creating word cloud using skull image for fake news which depict that
#fake news are dangerous

skull="/content/drive/MyDrive/skull-icon.png"
icon=Image.open(skull)
mask=Image.new(mode="RGB",size=icon.size, color=(255,255,255))
mask.paste(icon, box=icon)

rgb_array=np.array(mask)

# %%
#Fake News
plt.figure(figsize = (15,15))
Wc = WordCloud(mask=rgb_array,max_words = 2000 , width = 1600 ,
               height = 800)

Wc.generate(" ".join(df[df.category == 1].text))
plt.axis("off")
plt.imshow(Wc , interpolation = 'bilinear')

# %% [markdown]
# #Feature Extraction & and model building

# %%
#splitting the
from sklearn.model_selection import train_test_split
X=df["text"] #feature
y=df["category"] # traget
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#importing libraries to build a pipline
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
#this pipe line will take the text and vectorise it , and then TF-IDF, then fitting the model

text_clf=Pipeline([("tfidf",TfidfVectorizer()),("clf",LinearSVC())])
text_clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
#making prediction using the model
predictions=text_clf.predict(X_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7096
#            1       1.00      0.99      1.00      7506
#
#     accuracy                           1.00     14602
#    macro avg       1.00      1.00      1.00     14602
# weighted avg       1.00      1.00      1.00     14602

# %%
#overall acuracy
print(metrics.accuracy_score(y_test,predictions))
# Out:
# 0.9954115874537734

# %%
#confusion matrix
print(metrics.confusion_matrix(y_test,predictions))
# Out:
# [[7072   24]
#  [  43 7463]]
